# %%
# Mount drive 
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
path = "//content//gdrive//My Drive//My DeepLearning/"
import os
os.path.isdir(path)
# Out:
# True

# %%
from keras.applications.resnet50 import ResNet50
from keras.preprocessing import image
from keras.applications.resnet50 import preprocess_input, decode_predictions
import numpy as np

model = ResNet50(weights='imagenet')

# %%
#%cd /content/gdrive/'My Drive'/'My DeepLearning'/'Practice'
#!unzip 'Test Images.zip'
# Out:
# /content/gdrive/My Drive/My DeepLearning/Practice
# Archive:  Test Images.zip
#    creating: Test Images/
#   inflating: Test Images/Bird.jpg
#   inflating: Test Images/Bottle.png
#   inflating: Test Images/Cow.jpg
#   inflating: Test Images/Elephant.jpg
#   inflating: Test Images/Kanguru.jpg
#   inflating: Test Images/laptop.jfif
#   inflating: Test Images/Lion_waiting_in_Namibia.jpg
#   inflating: Test Images/Panda.jpg
#   inflating: Test Images/Peacock.jpg
#   inflating: Test Images/Projector.jpg
#   inflating: Test Images/TH True Milk.jpg

# %%
import os
base_path = path + "Test Images"
allfiles = os.listdir(base_path)

# %%
allfiles
# Out:
# ['Elephant.jpg',
#  'Lion_waiting_in_Namibia.jpg',
#  'Bird.jpg',
#  'Peacock.jpg',
#  'Panda.jpg',
#  'Cow.jpg',
#  'Kanguru.jpg',
#  'laptop.jfif',
#  'Projector.jpg',
#  'Bottle.png',
#  'TH True Milk.jpg',
#  'speaker.jpg',
#  'iphone.jpg',
#  'lo thuoc.jpg',
#  'pencil.jpeg',
#  'milktea.jpg',
#  'pencil.png',
#  'pencil.jpg',
#  'ipad.jpeg',
#  'ipad.jpg']

# %%
base_path
# Out:
# '//content//gdrive//My Drive//My DeepLearning/Test Images'

# %%
import matplotlib.pyplot as plt
for filename in allfiles:
    img_path = base_path + "//" + filename
    img = image.load_img(img_path, target_size=(224, 224))
    x = image.img_to_array(img)
    x = np.expand_dims(x, axis=0)
    x = preprocess_input(x) #đưa bức ảnh về đúng input

    preds = model.predict(x)
    # decode the results into a list of tuples (class, description, probability)
    # (one such list for each sample in the batch)
    # print('Predicted:', decode_predictions(preds, top=3)[0])
    plt.imshow(img)
    plt.show()
    display(decode_predictions(preds, top=3))
# Out:
# Output hidden; open in https://colab.research.google.com to view.
